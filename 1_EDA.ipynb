# %% [markdown]
# # FriskvårdsCentrum Nordic – Exploratory Data Analysis (EDA)
# Denna notebook utforskar datasetet innan ETL-pipelinen körs.

# %% [markdown]
# ## Data Dictionary
# member_id – unikt medlems-ID
# passdatum – datum då träningspasset sker
# bokningsdatum – datum då bokningen gjordes
# passnamn – typ av träningspass
# status – bokningsstatus
# anläggning – gymanläggning
# medlemstyp – typ av medlemskap
# födelseår – medlems födelseår
# månadskostnad – kostnad för medlemskap
# feedback_text – textfeedback från medlem

# %%
import pandas as pd
df = pd.read_csv('friskvard_data.csv')
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.isna().sum()

# %%
df['status'].value_counts()

# %%
df['passnamn'].value_counts().head(20)
